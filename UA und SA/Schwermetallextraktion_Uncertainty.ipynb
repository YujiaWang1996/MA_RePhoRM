# %%
import numpy as np
import sympy as sp


b10 = 17500
c10 = 7000
d10 = 12000
e78 = 81618
c342 = 0.025
c551 = 1099
b557 = 70700
c557 = 84567
c560 = 1989
c605 = 0.45
input_data = np.asarray([b10,c10,d10,e78,c342,c551,b557,c557,c560,c605])

def zielwertsuche(b590,b591,c590,c591):
    x = sp.Symbol('x')
    f = (b590+b591+x*31/98)/(c590+c591+x) -0.166
    x = sp.solve(f)
    return x

def model2(c67,c154,c160):
    faktor = [c67,c154,c160]
    c14 = 0.144
    c15 = 0.752
    c16 = 2.834
    c23 = input_data[2]
    c25 = input_data[2]*c16
    c26 = input_data[2]*c14
    c32 = input_data[2]*c15
    c89 = input_data[2]+c25+c26+c32
    c158 = 0.636
    c162 = c158*faktor[2]
    c213 = c89
    c215 = c213*faktor[1]
    c216 = c213-c215
    a158 = 0.541
    b158 = 0.459
    c203 = c216*a158
    c205 = c216*b158
    c207 = c205*c158
    c209 = c205*(1-c158)
    c222 = c207
    c220 = c222/c162
    c223 = 1-c162
    c224 = c220*c223
    c219 = c220/c216
    c218 = c216-c220
    c217 = c218/c216
    c218,c220,c224
    c228 = c23
    c229 = c26
    c230 = c32
    c231 = c222
    c232 = c162
    c233 = c215*c232
    c234 = c228+c229+c230-c231-c233
    c237 = c25
    c238 = c224
    c239 = 1-c162
    c240 = c215*c239
    c241 = c237-c238-c240
    b302 =1.02
    b303 = 0.02*faktor[0]
    c307 = c218
    c308 = 1.3
    c309 = c307/c308
    c311 = c309*b303
    c313 = c311*b302    
    b358 = input_data[4]
    b359 = input_data[4]
    b360 = input_data[4]
    f78 = input_data[2]*input_data[3]/1000000
    b136 = f78
    b260 = b136*0.56*(1-faktor[1])
    c358 = b260
    d358 = c358*input_data[4]
    b137 = c32*31/98
    c137 = b137
    b261 = c137*(1-faktor[1])
    c359 = b261
    d359 = c359*input_data[4]
    c360 = c358+c359
    d360 = c360*input_data[4]
    c367 = c218
    c368 = c313
    c369 = c367+c368
    a414 = 0.986
    b414 = 0.014
    c414 = 0.3
    c421 = c414*faktor[2]
    c446 = c369
    c447 = 0
    c448 = c446*c447
    c449 = c446-c448
    c455 = c449*b414*c414
    c470 = c455
    c469 = c421
    c468 = c470/c469
    c464 = c449
    c466 = c464-c468
    c465 = c466/c464
    c467 = c468/c464
    c471 = 1-c469
    c472 = c468*c471
    c373 = c234
    c374 = 0.05
    c375 = c313
    c376 = c374*c375
    c377 = c373+c376
    c476 = c377
    c477 = c470
    c478 = c421
    c479 = c448*c478
    c480 = c476-c477-c479
    c481 = c466
    c380 = c241
    c381 = 0.95
    c382 = c313
    c383 = c381*c382
    c384 = c380+c383
    c483 = c384
    c484 = c472
    c485 = 1-c478
    c486 = c448*c485
    c487 = c483-c484-c486
    d404 = d358
    b404 = b260
    c404 = b404-d404
    b506 = c404
    b577 = b506
    b287 = 0
    c578 = b287
    b286 = b136*0.44*(1-faktor[1])
    c577 = b286
    c579 = c577+c578
    d405 = d359
    b405 = b261
    c405 = b405-d405
    b507 = c405
    b578 = b507
    b579 = b577+b578
    b590 = b579+c579
    c590 = c480+c207
    d557 = input_data[0]*input_data[6]/1000000
    e557 = input_data[1]*input_data[7]/1000000
    f557 = d557+e557
    d577 = f557
    b591 = d577
    c591 = input_data[0]+input_data[1]
    c592 = zielwertsuche(b590, b591,c590,c591)[0]
    c597 = c592
    c598 = c597/0.75*0.25
    c599 = c597+c598
    c605 = input_data[-1]
    c606 = 1-c605
    c610 = c480
    c611 = c207
    c612 = input_data[0]
    c613 = input_data[1]
    c614 = c597
    c615 = c610+c611+c612+c613+c614
    c616 = c615/c605*c606
    c617 = c487
    c618 = c224
    c619 = c598
    c620 = c616-c617-c618-c619
    c633 = c466
    c634 = c205
    c635 = input_data[0]
    c636 = input_data[1]
    c637 = c599
    c638 = c620
    c639 = c633+c634+c635+c636+c637+c638
    c651 = c598
    c652 = c487
    c653 = c238
    c654 = c620
    c655 = c651+c652+c653+c654
    c648 = c615
    c688 = c648
    c689 = 0.95
    c690 = c688/c689
    c681 = 0.05
    c692 = c690*c681
    c693 = c655-c692
    c699 = c32
    c705 = c597
    c707 = c699+c705
    c709 = c707/c690
    b72 = 0.25
    d72 = b72*faktor[0]
    e72 = 656
    f72 = input_data[2]*e72/1000000
    g72 = d72*f72
    c130 = g72
    b254 = c130*(1-faktor[1])
    b398 = b254
    b353 = 0.99
    c353 = b254
    d353 = c353*b353
    d398 = d353
    c398 = b398-d398
    b500 = c398*(1-faktor[1])
    b571 = b500
    b668 = b571
    e72 = 656
    f72 = input_data[2]*e72/1000000
    b72 = 0.25
    d72 = b72*faktor[0]
    h72 = f72*(1-d72)
    d130 = h72
    b280 = d130*(1-faktor[1])
    c571 = b280
    c668 = c571
    d551 = input_data[0]*663/1000000
    e551 = input_data[1]*input_data[5]/1000000
    f551 = d551+e551
    d571 = f551
    d668 = d571
    f668 = b668+c668+d668
    g668 = c648
    h668 = f668/g668*1000000
    b729 = h668
    b77 = 0.30725
    d77 = b77*faktor[0]
    e77 = 125
    f77 = input_data[2]*e77/1000000
    g77 = d77*f77
    c135 = g77
    b259 = c135*(1-faktor[1])
    b403 = b259
    b357 = 0.025
    c357 = b259
    d357 = c357*b357
    d403 = d357
    c403 = b403-d403
    b505 = c403*(1-faktor[1])
    b576 = b505
    b673 = b576
    e77 = 125
    f77 = input_data[2]*e77/1000000
    b77 = 0.30725
    d77 = b77*faktor[0]
    h77 = f77*(1-d77)
    d135 = h77
    b285 = d135*(1-faktor[1])
    c576 = b285
    c673 = c576
    d556 = input_data[0]*64.5/1000000
    e556 = input_data[1]*47.6/1000000
    f556 = d556+e556 
    d576 = f556
    d673 = d576
    f673 = b673+c673+d673
    g673 = c648
    h673 = f673/g673*1000000
    b730 = h673
    
    b81 = 0.25701
    d81 = b81*faktor[0]
    e81 = 2353
    f81 = input_data[2]*e81/1000000
    g81 = d81*f81
    c145 = g81
    b269 = c145*(1-faktor[1])
    b409 = b269
    b363 = 0.95
    c363 = b269
    d363 = c363*b363
    d409 = d363
    c409 = b409-d409
    b511 = c409*(1-faktor[1])
    b582 = b511
    b677 = b582
    e81 = 2353
    f81 = input_data[2]*e81/1000000
    b81 = 0.25701
    d81 = b81*faktor[0]
    h81 = f81*(1-d81)
    d145 = h81
    b295 = d145*(1-faktor[1])
    c582 = b295
    c677 = c582
    d560 = input_data[0]*2260/1000000
    e560 = input_data[1]*1989/1000000
    f560 = d560+e560
    d582 = f560
    d677 = d582
    f677 = b677+c677+d677
    g677 = c648
    h677 = f677/g677*1000000
    b732 = h677

    output = [c313,c468,c620,c707,c693,c690,c709,b729,b732]
    return output

# %%
#  faktor = [c67,c154,c160]
model2(0.9,0.0128,1.0435)
# Out:
# [443.2705923778999,
#  427.03733216950417,
#  36233.8665907303,
#  23759.7494294679,
#  71805.9146088926,
#  64625.3231480033,
#  0.367653858767622,
#  412.669767671680,
#  1225.17060133496]

# %%
#定义抽样数量
sample_size = 30000

#定义faktor分布
f1 = np.reshape(np.random.uniform(low=0.66,high=0.9,size=sample_size),(sample_size,1))
f2 = np.reshape(np.random.triangular(0.0047,0.02,0.0242,size=sample_size),(sample_size,1))
f3 = np.reshape(np.random.uniform(low=1,high=1.082,size=sample_size),(sample_size,1))
faktor_sample=np.hstack((f1,f2,f3))

output_sample = []
for f in faktor_sample:
    output_sample.append(model2(f[0],f[1],f[2]))

# %%
#可视化
import matplotlib.pyplot as plt

# %%
output = []
for i in range(9):
    y = np.asarray(output_sample,dtype=float)[:,i]
    plt.hist(y, bins=40, facecolor="blue", edgecolor="black", alpha=0.7)
    plt.show()
    output.append(y)
np.shape(output)
# Out:
# (9, 30000)

# %%
plt.boxplot(output,showmeans = True, )
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25bb1bf5430>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25bb1bf5af0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25bb1bf50d0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x25bb1c031f0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x25bb1c03880>,
# ...
#  'means': [<matplotlib.lines.Line2D at 0x25bb1c03550>,
# ...
#   <matplotlib.lines.Line2D at 0x25bb22d3490>]}

# %%
np.shape(output)
# Out:
# (9, 30000)

# %%
plt.boxplot([output[0],output[1],output[6],output[7],output[8]],showmeans = True, )
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25bb2394130>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25bb23947f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25bb2343d90>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x25bb2394e80>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x25bb239f520>,
# ...
#  'means': [<matplotlib.lines.Line2D at 0x25bb239f1f0>,
# ...
#   <matplotlib.lines.Line2D at 0x25bb23ea970>]}

# %%
plt.boxplot(output[-1],showmeans = True, )
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25bb2413400>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25bb2413ac0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25bb24130a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x25bb24211c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25bb2421850>],
#  'means': [<matplotlib.lines.Line2D at 0x25bb2421520>]}

# %%
np.savetxt('Schwermetallextraktion_Uncertianty',output,fmt='%f',delimiter=',')

# %%
#应该把不同的Model的Output进行横向对比
#output通过Pandas存到dataframe，然后把另外的模型做出来，再画图。

# %%
testload = np.loadtxt('Schwermetallextraktion_Uncertianty',delimiter=',')

# %%
testload.shape
# Out:
# (9, 30000)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

#  output = [c313,c468,c620,c707,c693,c690,c709,b729,b732]
fig, axes = plt.subplots(3, 3, figsize=(12, 12))
var_names=['Fällmittel','Abfall','Wasser für TR-Einstellung','Gesamtphosphorsäure(100%)','Verdampftes Wasser','Düngemittel-Produkt','P-Säure/Düngemittel-Produkt','Kupfergehalt im Düngemittel-Produkt','Zinkgehalt im Düngemittel-Produkt']
df = pd.DataFrame(testload.T, columns=var_names)

# 循环绘制小提琴图
for i, ax in enumerate(axes.flat):
    sns.violinplot(x='variable', y='value', data=pd.melt(df.iloc[:, i:i+1]), ax=ax)
    
# 调整子图间距
plt.subplots_adjust(wspace=0.4, hspace=0.4)

# 显示图像
plt.show()

# %%
np.set_printoptions(threshold=np.inf)
row_max = np.amax(testload, axis=1)
print("Max:" , row_max)
row_min = np.amin(testload, axis=1)
print("Min", row_min)
# Out:
# Max: [4.56344782e+02 4.33164097e+02 3.66960269e+04 2.39006082e+04
#  7.23292128e+04 6.50962915e+04 3.68599000e-01 4.23542497e+02
#  1.26094445e+03]
# Min [3.12649318e+02 4.17264533e+02 3.56706847e+04 2.35349477e+04
#  7.10169425e+04 6.39152482e+04 3.67073000e-01 4.10758817e+02
#  1.22002811e+03]
