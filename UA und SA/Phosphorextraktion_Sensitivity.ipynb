# %%
import numpy as np
import sympy as sp
from SALib.sample import saltelli
from SALib.analyze import sobol
#input_data = np.asarray([b10,c10,d10,b78,e78,c209,c512,b518,c518,c521,c566,c67,c322,c330,b81,b77,b235,b224])
def zielwertsuche(b551,b552,c551,c552):
    x = sp.Symbol('x')
    f = (b551+b552+x*31/98)/(c551+c552+x) -0.166
    x = sp.solve(f)
    return x

def model1(input_data):
    faktor = [input_data[-7],input_data[-6],input_data[-5]]
    wk = 2.834
    ssk = 0.3
    psk = 0.55
    b512 = 663
    b517 = 65
    c23 = input_data[2]
    c25 = input_data[2] * wk
    c26 = input_data[2] * ssk
    c31 = input_data[2] * psk
    f78 = input_data[2] * input_data[4]/1000000
    RIP = input_data[3] * faktor[0]
    g78 = RIP * f78
    h78 = f78 * (1-RIP)
    c89 = c23+c25+c26+c31
    #suspension1
    b152 = 0.018
    c157 = 1.3
    c158 = c89/c157
    c160 = c158 * b152
    c161 = 1.02
    c162 = c160*c161
    c225 = g78
    d225 = c225 * input_data[5]
    c226 = 2088
    d226 = c226 * input_data[5]
    c227 = c225+c226
    d227 = c227 * input_data[5]
    c241 = c89+c162
    #suspension2
    a326 = 0.62634
    b326 = 0.37365
    c326 = 0.40943
    c335 = 1.5
    c337 = c335*c23
    c387 = c241+c337
    c390 =c387*(1-faktor[1])
    c392 = c390*a326
    c394 = c390*b326
    c396 = c394*c326 
    c407 = c390
    c413 = c396
    c411 = c413/input_data[-5]
    c409 = c407-c411
    c408 = c409/c407
    c410 = c411/c407
    c415 = c411 * (1-input_data[-5])
    c431 = c25
    c432 = 0.95
    c433 = c162
    c434 = c432*c433
    c435 = c337
    c436 = c415
    c437 = 1-input_data[-5]
    c438 = c437 * faktor[1] * (c337+c241)
    c439 = c431+c434+c435-c436-c438
    d518 = input_data[0] * input_data[7]/1000000
    e518 = input_data[1] * input_data[8]/1000000
    f518 = d518+e518
    zwischen1 = input_data[2]*input_data[4]/1000000*input_data[3]*faktor[0]
    zwischen2 = input_data[2]*input_data[4]/1000000*(1-input_data[3]*faktor[0])
    b538 = (input_data[2]*input_data[4]/1000000-zwischen1*input_data[5]-zwischen2)*(1-faktor[1])
    b539 = c31*31/98*(1-input_data[5])*(1-faktor[1])
    b540 =b538+b539
    b551 = b540
    b552 = f518
    c427 = faktor[2]*faktor[1] * (c337+c241)
    c551 = c23+c26+c31+0.05*c162-c413-c427
    c552 =input_data[0]+input_data[1]
    c553 = zielwertsuche(b551,b552,c551,c552)[0]
    c575 = c551+input_data[0]+input_data[1]+c553
    c576 = c575/input_data[-8]*(1-input_data[-8])
    c577 = c439
    c559 = c553/0.75*0.25
    c578 =c559
    c579 = c576-c577-c578
    e72 =656
    f72 = input_data[2]*e72/1000000
    g72 = f72*0.233623*faktor[0]
    h72 = f72*(1-0.233623*faktor[0])
    d220 = f72*0.233623*faktor[0]*0.99
    c295 = f72- f72*(1-0.233623*faktor[0])-f72*0.233623*faktor[0]*0.99
    b452 =c295*(1-faktor[1])
    b624 = b452
    f512 = (input_data[0]*b512+input_data[1]*input_data[6])/1000000
    c624 = f512
    e624 = b624+c624
    f624 = c575
    g624 =e624/f624*1000000
    b686 =g624
    e77 =125
    f77 = input_data[2]*e77/1000000
    g77 = f77*input_data[-3]*faktor[0]
    h77 = f77*(1-input_data[-3]*faktor[0])
    d224 = f77*input_data[-3]*faktor[0]*input_data[-1]
    c300 = f77- f77*(1-input_data[-3]*faktor[0])-f77*input_data[-3]*faktor[0]*input_data[-1]
    b457 =c300*(1-faktor[1])
    b629 = b457
    f517 = (input_data[0]*b517+input_data[1]*47.6)/1000000
    c629 = f517
    e629 = b629+c629
    f629 = c575
    g629 =e629/f629*1000000
    b687 =g629
    e81 =2353
    f81 = input_data[2]*e81/1000000
    g81 = f81*input_data[-4]*faktor[0]
    h81 = f81*(1-input_data[-4]*faktor[0])
    d235 = f81*input_data[-4]*faktor[0]*input_data[-2]
    c311 = f81- f81*(1-input_data[-4]*faktor[0])-f81*input_data[-4]*faktor[0]*input_data[-2]
    b468 =c311*(1-faktor[1])
    b633 = b468
    f521 = (input_data[0]*2260+input_data[1]*input_data[9])/1000000
    c633 = f521
    e633 = b633+c633
    f633 = c575
    g633 =e633/f633*1000000
    b689 =g633
    c644 = c575
    c645 = 0.95
    c646 = c644/c645
    c647 = 0.05
    c648 = c646*c647
    c649 = c576-c648
    c650 = c649/c646
    c655 = c31
    c662 = c553
    c664 = c655+c662
    c666 = c664/c646
    
    
    output = [c162, c411, c579, c664, c649, c646, c666, c650, c408, c410, b686, b687, b689]
    return output

# %%
#input_data = np.asarray([b10,c10,d10,b78,e78,c209,c512,b518,c518,c521,c566,c67,c322,c330, b72, b77, b220, b224])
model1([17500,7000,8000,0.87583,81618,0.025,1099,70700,84567,1989,0.45,0.9,0.0128,0.4278,0.43789,0.43577,0.95,0.025])
# Out:
# [529.2199384615384,
#  17651.82506809089,
#  23046.7726047354,
#  14810.1419608655,
#  49019.1269163409,
#  44117.2142247068,
#  0.335699844632788,
#  1.11111111111111,
#  0.6423947650771389,
#  0.35760523492286117,
#  460.648287914794,
#  44.0976835970219,
#  1284.59654654845]

# %%
model1([17500,7000,12000,0.87583,81618,0.025,1099,70700,84567,1989,0.45,0.9,0.0128,0.4278,0.43789,0.43577,0.95,0.025])
# Out:
# [793.8299076923076,
#  26477.73760213633,
#  12981.8767699564,
#  14772.1455370083,
#  50495.8630010728,
#  45446.2767009655,
#  0.325046331830621,
#  1.11111111111111,
#  0.6423947650771389,
#  0.35760523492286117,
#  447.302924687134,
#  47.1798341946511,
#  1251.26966326067]

# %%
#input_data = np.asarray([b10,c10,d10,b78,e78,c209,c512,b518,c518,c521,c566,c67,c322,c330,b72,b77,b220,b224])
problem = {
    'num_vars': 18,
    'names': ['x1', 'x2', 'x3','x4','x5','x6','x7','x8','x9','x10','x11','x12','x13','x14','x15','x16','x17','x18'],
    'bounds': [[13500, 21500],
                [3000, 11000],
                [8000, 16000],
                [0.7, 1.0],
                [60000, 90000],
                [0, 0.15],
                [800, 1400],
                [60000, 90000],
                [75000, 105000],
                [1000, 3500],
                [0.45, 0.50],
                [0.60, 0.95],
                [0.001, 0.05],
                [0.30, 0.80],
                [0.30, 0.60],
                [0.30, 0.50],
                [0.80, 1.00],
                [0.00, 0.15]]
}
param_values = saltelli.sample(problem, 128)
# Out:
# C:\Users\zhang\AppData\Local\Temp\ipykernel_21984\204214929.py:24: DeprecationWarning: `salib.sample.saltelli` will be removed in SALib 1.5. Please use `salib.sample.sobol`
#   param_values = saltelli.sample(problem, 128)

# %%
param_values
# Out:
# array([[1.35937500e+04, 5.65625000e+03, 1.03437500e+04, ...,
#         4.52343750e-01, 9.13281250e-01, 5.33203125e-02],
#        [1.41562500e+04, 5.65625000e+03, 1.03437500e+04, ...,
#         4.52343750e-01, 9.13281250e-01, 5.33203125e-02],
#        [1.35937500e+04, 7.46875000e+03, 1.03437500e+04, ...,
#         4.52343750e-01, 9.13281250e-01, 5.33203125e-02],
#        ...,
#        [1.93437500e+04, 5.03125000e+03, 1.05312500e+04, ...,
#         4.36718750e-01, 8.80468750e-01, 1.30664062e-01],
#        [1.93437500e+04, 5.03125000e+03, 1.05312500e+04, ...,
#         4.36718750e-01, 9.08593750e-01, 6.38671875e-02],
#        [1.93437500e+04, 5.03125000e+03, 1.05312500e+04, ...,
#         4.36718750e-01, 9.08593750e-01, 1.30664062e-01]])

# %%
np.shape(param_values)
# Out:
# (4864, 18)

# %%
Y=[]
for i in param_values:
    y = model1(i)
    Y.append(y)

# %%
Y_ = np.asarray(Y,dtype=float)

# %%
for index in range(Y_.shape[1]):
    output = Y_[:,index]
    Si = sobol.analyze(problem, output)
    
    print("Ergebnisse der Sensitivitätsanalyse von output: %d\n\n"%index)
    for i in range(len(Si['ST'])):
        print("Gesamtsensitivität von input%d: %f" %(i,Si['S1'][i]))
    print("--------------------------------------------------------------\n\n")
# Out:
# Ergebnisse der Sensitivitätsanalyse von output: 0
#
#
# Gesamtsensitivität von input0: 0.000000
# Gesamtsensitivität von input1: 0.000000
# Gesamtsensitivität von input2: 1.008606
# Gesamtsensitivität von input3: 0.000000
# Gesamtsensitivität von input4: 0.000000
# Gesamtsensitivität von input5: 0.000000
# Gesamtsensitivität von input6: 0.000000
# Gesamtsensitivität von input7: 0.000000
# Gesamtsensitivität von input8: 0.000000
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.000000
# Gesamtsensitivität von input11: 0.000000
# Gesamtsensitivität von input12: 0.000000
# Gesamtsensitivität von input13: 0.000000
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 1
#
#
# Gesamtsensitivität von input0: 0.000000
# Gesamtsensitivität von input1: 0.000000
# Gesamtsensitivität von input2: 0.230889
# Gesamtsensitivität von input3: 0.000000
# Gesamtsensitivität von input4: 0.000000
# Gesamtsensitivität von input5: 0.000000
# Gesamtsensitivität von input6: 0.000000
# Gesamtsensitivität von input7: 0.000000
# Gesamtsensitivität von input8: 0.000000
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.000000
# Gesamtsensitivität von input11: 0.000000
# Gesamtsensitivität von input12: -0.000153
# Gesamtsensitivität von input13: 0.593871
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 2
#
#
# Gesamtsensitivität von input0: 0.106092
# Gesamtsensitivität von input1: 0.105619
# Gesamtsensitivität von input2: 0.398293
# Gesamtsensitivität von input3: 0.000985
# Gesamtsensitivität von input4: 0.002399
# Gesamtsensitivität von input5: -0.003659
# Gesamtsensitivität von input6: 0.000000
# Gesamtsensitivität von input7: 0.004408
# Gesamtsensitivität von input8: 0.000336
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.060496
# Gesamtsensitivität von input11: 0.001625
# Gesamtsensitivität von input12: -0.000832
# Gesamtsensitivität von input13: 0.401885
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 3
#
#
# Gesamtsensitivität von input0: 0.348710
# Gesamtsensitivität von input1: 0.283784
# Gesamtsensitivität von input2: 0.004764
# Gesamtsensitivität von input3: 0.029012
# Gesamtsensitivität von input4: 0.026360
# Gesamtsensitivität von input5: 0.092989
# Gesamtsensitivität von input6: 0.000000
# Gesamtsensitivität von input7: 0.175410
# Gesamtsensitivität von input8: 0.037754
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.000000
# Gesamtsensitivität von input11: 0.043699
# Gesamtsensitivität von input12: 0.013637
# Gesamtsensitivität von input13: 0.015015
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 4
#
#
# Gesamtsensitivität von input0: 0.378863
# Gesamtsensitivität von input1: 0.391227
# Gesamtsensitivität von input2: 0.022210
# Gesamtsensitivität von input3: 0.004989
# Gesamtsensitivität von input4: 0.007281
# Gesamtsensitivität von input5: 0.012329
# Gesamtsensitivität von input6: 0.000000
# Gesamtsensitivität von input7: 0.029527
# Gesamtsensitivität von input8: 0.005529
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.193716
# Gesamtsensitivität von input11: 0.007134
# Gesamtsensitivität von input12: 0.011281
# Gesamtsensitivität von input13: 0.010246
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 5
#
#
# Gesamtsensitivität von input0: 0.471134
# Gesamtsensitivität von input1: 0.485482
# Gesamtsensitivität von input2: 0.023861
# Gesamtsensitivität von input3: 0.004850
# Gesamtsensitivität von input4: 0.006304
# Gesamtsensitivität von input5: 0.015213
# Gesamtsensitivität von input6: 0.000000
# Gesamtsensitivität von input7: 0.033942
# Gesamtsensitivität von input8: 0.007813
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.000000
# Gesamtsensitivität von input11: 0.009965
# Gesamtsensitivität von input12: 0.017531
# Gesamtsensitivität von input13: 0.008509
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 6
#
#
# Gesamtsensitivität von input0: -0.009819
# Gesamtsensitivität von input1: 0.028416
# Gesamtsensitivität von input2: -0.010164
# Gesamtsensitivität von input3: 0.073510
# Gesamtsensitivität von input4: 0.049883
# Gesamtsensitivität von input5: 0.259623
# Gesamtsensitivität von input6: 0.000000
# Gesamtsensitivität von input7: 0.397155
# Gesamtsensitivität von input8: 0.077628
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.000000
# Gesamtsensitivität von input11: 0.104321
# Gesamtsensitivität von input12: -0.000246
# Gesamtsensitivität von input13: 0.014269
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 7
#
#
# Gesamtsensitivität von input0: -0.000000
# Gesamtsensitivität von input1: -0.000000
# Gesamtsensitivität von input2: 0.000000
# Gesamtsensitivität von input3: -0.000000
# Gesamtsensitivität von input4: -0.000000
# Gesamtsensitivität von input5: -0.000000
# Gesamtsensitivität von input6: 0.000000
# Gesamtsensitivität von input7: -0.000000
# Gesamtsensitivität von input8: -0.000000
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 1.012153
# Gesamtsensitivität von input11: 0.000000
# Gesamtsensitivität von input12: -0.000000
# Gesamtsensitivität von input13: -0.000000
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 8
#
#
# Gesamtsensitivität von input0: 0.000000
# Gesamtsensitivität von input1: 0.000000
# Gesamtsensitivität von input2: -0.000000
# Gesamtsensitivität von input3: 0.000000
# Gesamtsensitivität von input4: 0.000000
# Gesamtsensitivität von input5: 0.000000
# Gesamtsensitivität von input6: 0.000000
# Gesamtsensitivität von input7: 0.000000
# Gesamtsensitivität von input8: 0.000000
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.000000
# Gesamtsensitivität von input11: 0.000000
# Gesamtsensitivität von input12: -0.000000
# Gesamtsensitivität von input13: 0.989823
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 9
#
#
# Gesamtsensitivität von input0: 0.000000
# Gesamtsensitivität von input1: 0.000000
# Gesamtsensitivität von input2: -0.000000
# Gesamtsensitivität von input3: 0.000000
# Gesamtsensitivität von input4: 0.000000
# Gesamtsensitivität von input5: 0.000000
# Gesamtsensitivität von input6: 0.000000
# Gesamtsensitivität von input7: 0.000000
# Gesamtsensitivität von input8: 0.000000
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.000000
# Gesamtsensitivität von input11: 0.000000
# Gesamtsensitivität von input12: -0.000000
# Gesamtsensitivität von input13: 0.989823
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
# Ergebnisse der Sensitivitätsanalyse von output: 10
#
#
# Gesamtsensitivität von input0: 0.010903
# Gesamtsensitivität von input1: 0.310281
# Gesamtsensitivität von input2: 0.042700
# Gesamtsensitivität von input3: 0.001572
# Gesamtsensitivität von input4: 0.009506
# Gesamtsensitivität von input5: 0.034661
# Gesamtsensitivität von input6: 0.432212
# Gesamtsensitivität von input7: 0.061431
# Gesamtsensitivität von input8: 0.008528
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.000000
# Gesamtsensitivität von input11: 0.005077
# Gesamtsensitivität von input12: 0.036103
# Gesamtsensitivität von input13: 0.016263
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 11
#
#
# Gesamtsensitivität von input0: -0.015926
# Gesamtsensitivität von input1: 0.106948
# Gesamtsensitivität von input2: 0.090396
# Gesamtsensitivität von input3: 0.014316
# Gesamtsensitivität von input4: -0.004330
# Gesamtsensitivität von input5: 0.057036
# Gesamtsensitivität von input6: 0.000000
# Gesamtsensitivität von input7: 0.063191
# Gesamtsensitivität von input8: 0.011448
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.000000
# Gesamtsensitivität von input11: 0.335200
# Gesamtsensitivität von input12: 0.036058
# Gesamtsensitivität von input13: 0.037476
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.170527
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.039332
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 12
#
#
# Gesamtsensitivität von input0: 0.017349
# Gesamtsensitivität von input1: 0.032300
# Gesamtsensitivität von input2: 0.021496
# Gesamtsensitivität von input3: 0.009361
# Gesamtsensitivität von input4: 0.005047
# Gesamtsensitivität von input5: 0.025293
# Gesamtsensitivität von input6: 0.000000
# Gesamtsensitivität von input7: 0.047566
# Gesamtsensitivität von input8: 0.009641
# Gesamtsensitivität von input9: 0.727161
# Gesamtsensitivität von input10: 0.000000
# Gesamtsensitivität von input11: 0.018603
# Gesamtsensitivität von input12: 0.026798
# Gesamtsensitivität von input13: 0.020260
# Gesamtsensitivität von input14: 0.001846
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.003706
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
