# %%
from SALib.sample import saltelli
from SALib.analyze import sobol
import numpy as np
import sympy as sp


b10 = 17500
c10 = 7000
d10 = 12000
e78 = 81618
c342 = 0.025
c551 = 1099
b557 = 70700
c557 = 84567
c560 = 1989
c605 = 0.45

#input_data = np.asarray([b10,c10,d10,e78,c342,c551,b557,c557,c560,c605,c67,c154,c162,c421,b81,b77,b363,b357])
def zielwertsuche(b590,b591,c590,c591):
    x = sp.Symbol('x')
    f = (b590+b591+x*31/98)/(c590+c591+x) -0.166
    x = sp.solve(f)
    return x

def model2(input_data):
    c14 = 0.144
    c15 = 0.752
    c16 = 2.834
    faktor = [input_data[-8],input_data[-7]]
    c23 = input_data[2]
    c25 = input_data[2]*c16
    c26 = input_data[2]*c14
    c32 = input_data[2]*c15
    c89 = input_data[2]+c25+c26+c32
    c158 = 0.636
    c213 = c89
    c215 = c213*faktor[1]
    c216 = c213-c215
    a158 = 0.541
    b158 = 0.459
    c203 = c216*a158
    c205 = c216*b158
    c207 = c205*c158
    c209 = c205*(1-c158)
    c222 = c207
    c220 = c222/input_data[12]
    c223 = 1-input_data[12]
    c224 = c220*c223
    c219 = c220/c216
    c218 = c216-c220
    c217 = c218/c216
    c218,c220,c224
    c228 = c23
    c229 = c26
    c230 = c32
    c231 = c222
    c232 = input_data[12]
    c233 = c215*c232
    c234 = c228+c229+c230-c231-c233
    c237 = c25
    c238 = c224
    c239 = 1-input_data[12]
    c240 = c215*c239
    c241 = c237-c238-c240
    b302 =1.02
    b303 = 0.02*input_data[10]
    c307 = c218
    c308 = 1.3
    c309 = c307/c308
    c311 = c309*b303
    c313 = c311*b302    
    b358 = input_data[4]
    b359 = input_data[4]
    b360 = input_data[4]
    f78 = input_data[2]*input_data[3]/1000000
    b136 = f78
    b260 = b136*0.56*(1-faktor[1])
    c358 = b260
    d358 = c358*input_data[4]
    b137 = c32*31/98
    c137 = b137
    b261 = c137*(1-faktor[1])
    c359 = b261
    d359 = c359*input_data[4]
    c360 = c358+c359
    d360 = c360*input_data[4]
    c367 = c218
    c368 = c313
    c369 = c367+c368
    a414 = 0.986
    b414 = 0.014
    c414 = 0.3
    c446 = c369
    c447 = 0
    c448 = c446*c447
    c449 = c446-c448
    c455 = c449*b414*c414
    c470 = c455
    c469 = input_data[13]
    c468 = c470/c469
    c464 = c449
    c466 = c464-c468
    c465 = c466/c464
    c467 = c468/c464
    c471 = 1-c469
    c472 = c468*c471
    c373 = c234
    c374 = 0.05
    c375 = c313
    c376 = c374*c375
    c377 = c373+c376
    c476 = c377
    c477 = c470
    c478 = input_data[13]
    c479 = c448*c478
    c480 = c476-c477-c479
    c481 = c466
    c380 = c241
    c381 = 0.95
    c382 = c313
    c383 = c381*c382
    c384 = c380+c383
    c483 = c384
    c484 = c472
    c485 = 1-c478
    c486 = c448*c485
    c487 = c483-c484-c486
    d404 = d358
    b404 = b260
    c404 = b404-d404
    b506 = c404
    b577 = b506
    b287 = 0
    c578 = b287
    b286 = b136*0.44*(1-faktor[1])
    c577 = b286
    c579 = c577+c578
    d405 = d359
    b405 = b261
    c405 = b405-d405
    b507 = c405
    b578 = b507
    b579 = b577+b578
    b590 = b579+c579
    c590 = c480+c207
    d557 = input_data[0]*input_data[6]/1000000
    e557 = input_data[1]*input_data[7]/1000000
    f557 = d557+e557
    d577 = f557
    b591 = d577
    c591 = input_data[0]+input_data[1]
    c592 = zielwertsuche(b590, b591,c590,c591)[0]
    c597 = c592
    c598 = c597/0.75*0.25
    c599 = c597+c598
    c605 = input_data[9]
    c606 = 1-c605
    c610 = c480
    c611 = c207
    c612 = input_data[0]
    c613 = input_data[1]
    c614 = c597
    c615 = c610+c611+c612+c613+c614
    c616 = c615/c605*c606
    c617 = c487
    c618 = c224
    c619 = c598
    c620 = c616-c617-c618-c619
    c633 = c466
    c634 = c205
    c635 = input_data[0]
    c636 = input_data[1]
    c637 = c599
    c638 = c620
    c639 = c633+c634+c635+c636+c637+c638
    c651 = c598
    c652 = c487
    c653 = c238
    c654 = c620
    c655 = c651+c652+c653+c654
    c648 = c615
    c688 = c648
    c689 = 0.95
    c690 = c688/c689
    c681 = 0.05
    c692 = c690*c681
    c693 = c655-c692
    c694 = c693/c690
    c699 = c32
    c705 = c597
    c707 = c699+c705
    c709 = c707/c690

    b72 = 0.24757
    d72 = 0.24757*faktor[0]
    e72 = 656
    f72 = input_data[2]*e72/1000000
    g72 = d72*f72
    c130 = g72
    b254 = c130*(1-faktor[1])
    b398 = b254
    b353 = 0.99
    c353 = b254
    d353 = c353*b353
    d398 = d353
    c398 = b398-d398
    b500 = c398
    b571 = b500
    b668 = b571
    e72 = 656
    f72 = input_data[2]*e72/1000000
    b72 = 0.24757
    b72 = 0.24757*faktor[0]
    h72 = f72*(1-d72)
    d130 = h72
    b280 = d130*(1-faktor[1])
    c571 = b280
    c668 = c571
    d551 = input_data[0]*663/1000000
    e551 = input_data[1]*input_data[5]/1000000
    f551 = d551+e551
    d571 = f551
    d668 = d571
    f668 = b668+c668+d668
    g668 = c648
    h668 = f668/g668*1000000
    b729 = h668
    
    d77 = input_data[-3]*faktor[0]
    e77 = 125
    f77 = input_data[2]*e77/1000000
    g77 = d77*f77
    c135 = g77
    b259 = c135*(1-faktor[1])
    b403 = b259
    c357 = b259
    d357 = c357*input_data[-1]
    d403 = d357
    c403 = b403-d403
    b505 = c403
    b576 = b505
    b673 = b576
    e77 = 125
    f77 = input_data[2]*e77/1000000
    d77 = input_data[-3]*faktor[0]
    h77 = f77*(1-d77)
    d135 = h77
    b285 = d135*(1-faktor[1])
    c576 = b285
    c673 = c576
    d556 = input_data[0]*64.5/1000000
    e556 = input_data[1]*47.6/1000000
    f556 = d556+e556 
    d576 = f556
    d673 = d576
    f673 = b673+c673+d673
    g673 = c648
    h673 = f673/g673*1000000
    b730 = h673 
    
    d81 = input_data[-4]*faktor[0]
    e81 = 2353
    f81 = input_data[2]*e81/1000000
    g81 = d81*f81
    c145 = g81
    b269 = c145*(1-faktor[1])
    b409 = b269
    c363 = b269
    d363 = c363*input_data[-2]
    d409 = d363
    c409 = b409-d409
    b511 = c409
    b582 = b511
    b677 = b582
    e81 = 2353
    f81 = input_data[2]*e81/1000000
    d81 = input_data[-4]*faktor[0]
    h81 = f81*(1-d81)
    d145 = h81
    b295 = d145*(1-faktor[1])
    c582 = b295
    c677 = c582
    d560 = input_data[0]*2260/1000000
    e560 = input_data[1]*input_data[8]/1000000
    f560 = d560+e560
    d582 = f560
    d677 = d582
    f677 = b677+c677+d677
    g677 = c648
    h677 = f677/g677*1000000
    b732 = h677

    output = [c313,c468,c620,c690,c693,c707,c709,c694,b729,b730,b732]
    return output

# %%
model2([17500,7000,12000,81618,0.025,1099,70700,84567,1989,0.45,0.9,0.0128,0.66367,0.31305,0.25701,0.30725,0.95,0.025])
# Out:
# [443.2726903750547,
#  427.0393533347322,
#  36233.8555122852,
#  64625.3155417845,
#  71805.9061575384,
#  23759.7456374980,
#  0.367653843363221,
#  1.11111111111111,
#  412.947523171472,
#  47.7654276878530,
#  1225.23795872955]

# %%
#input_data = np.asarray([b10,c10,d10,e78,c342,c551,b557,c557,c560,c605,c67,c154,c162,c421,b81,b77,b363,b357])
problem = {
    'num_vars': 18,
    'names': ['x1', 'x2', 'x3','x4','x5','x6','x7','x8','x9','x10','x11','x12','x13','x14'],
    'bounds': [[13500, 21500],
                [3000, 11000],
                [8000, 16000],
                [60000, 90000],
                [0, 0.15],
                [800, 1400],
                [60000, 90000],
                [75000, 105000],
                [1000, 3500],
                [0.45, 0.50],
                [0.60, 0.95],
                [0.001, 0.05],
                [0.4, 0.8],
                [0.20, 0.60],
                [0.10, 0.40],
                [0.15,0.45],
                [0.8,1.0],
                [0,0.15]]
}
param_values = saltelli.sample(problem, 128)
# Out:
# C:\Users\zhang\AppData\Local\Temp\ipykernel_45916\3624292120.py:24: DeprecationWarning: `salib.sample.saltelli` will be removed in SALib 1.5. Please use `salib.sample.sobol`
#   param_values = saltelli.sample(problem, 128)

# %%
param_values
# Out:
# array([[1.35937500e+04, 5.65625000e+03, 1.03437500e+04, ...,
#         3.78515625e-01, 9.13281250e-01, 5.33203125e-02],
#        [1.41562500e+04, 5.65625000e+03, 1.03437500e+04, ...,
#         3.78515625e-01, 9.13281250e-01, 5.33203125e-02],
#        [1.35937500e+04, 7.46875000e+03, 1.03437500e+04, ...,
#         3.78515625e-01, 9.13281250e-01, 5.33203125e-02],
#        ...,
#        [1.93437500e+04, 5.03125000e+03, 1.05312500e+04, ...,
#         3.55078125e-01, 8.80468750e-01, 1.30664062e-01],
#        [1.93437500e+04, 5.03125000e+03, 1.05312500e+04, ...,
#         3.55078125e-01, 9.08593750e-01, 6.38671875e-02],
#        [1.93437500e+04, 5.03125000e+03, 1.05312500e+04, ...,
#         3.55078125e-01, 9.08593750e-01, 1.30664062e-01]])

# %%
np.shape(param_values)
# Out:
# (4864, 18)

# %%
Y=[]
for i in param_values:
    y = model2(i)
    Y.append(y)

# %%
Y_ = np.asarray(Y,dtype=float)

# %%
for index in range(Y_.shape[1]):
    output = Y_[:,index]
    Si = sobol.analyze(problem, output)
    
    print("Ergebnisse der Sensitivitätsanalyse von output: %d\n\n"%index)
    for i in range(len(Si['ST'])):
        print("Gesamtsensitivität von input%d: %f" %(i,Si['ST'][i]))
    print("--------------------------------------------------------------\n\n")
# Out:
# Ergebnisse der Sensitivitätsanalyse von output: 0
#
#
# Gesamtsensitivität von input0: 0.000000
# Gesamtsensitivität von input1: 0.000000
# Gesamtsensitivität von input2: 0.433410
# Gesamtsensitivität von input3: 0.000000
# Gesamtsensitivität von input4: 0.000000
# Gesamtsensitivität von input5: 0.000000
# Gesamtsensitivität von input6: 0.000000
# Gesamtsensitivität von input7: 0.000000
# Gesamtsensitivität von input8: 0.000000
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.187819
# Gesamtsensitivität von input11: 0.002285
# Gesamtsensitivität von input12: 0.420926
# Gesamtsensitivität von input13: 0.000000
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 1
#
#
# Gesamtsensitivität von input0: 0.000000
# Gesamtsensitivität von input1: 0.000000
# Gesamtsensitivität von input2: 0.181243
# Gesamtsensitivität von input3: 0.000000
# Gesamtsensitivität von input4: 0.000000
# Gesamtsensitivität von input5: 0.000000
# Gesamtsensitivität von input6: 0.000000
# Gesamtsensitivität von input7: 0.000000
# Gesamtsensitivität von input8: 0.000000
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.000014
# Gesamtsensitivität von input11: 0.001244
# Gesamtsensitivität von input12: 0.234240
# Gesamtsensitivität von input13: 0.546029
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 2
#
#
# Gesamtsensitivität von input0: 0.297343
# Gesamtsensitivität von input1: 0.267856
# Gesamtsensitivität von input2: 0.061577
# Gesamtsensitivität von input3: 0.005703
# Gesamtsensitivität von input4: 0.012728
# Gesamtsensitivität von input5: 0.000000
# Gesamtsensitivität von input6: 0.013964
# Gesamtsensitivität von input7: 0.002934
# Gesamtsensitivität von input8: 0.000000
# Gesamtsensitivität von input9: 0.347828
# Gesamtsensitivität von input10: 0.000033
# Gesamtsensitivität von input11: 0.004673
# Gesamtsensitivität von input12: 0.009064
# Gesamtsensitivität von input13: 0.000256
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 3
#
#
# Gesamtsensitivität von input0: 0.285108
# Gesamtsensitivität von input1: 0.250534
# Gesamtsensitivität von input2: 0.415314
# Gesamtsensitivität von input3: 0.008978
# Gesamtsensitivität von input4: 0.019002
# Gesamtsensitivität von input5: 0.000000
# Gesamtsensitivität von input6: 0.021574
# Gesamtsensitivität von input7: 0.004441
# Gesamtsensitivität von input8: 0.000000
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.000000
# Gesamtsensitivität von input11: 0.010450
# Gesamtsensitivität von input12: 0.004307
# Gesamtsensitivität von input13: 0.000000
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 4
#
#
# Gesamtsensitivität von input0: 0.222780
# Gesamtsensitivität von input1: 0.195084
# Gesamtsensitivität von input2: 0.322857
# Gesamtsensitivität von input3: 0.006887
# Gesamtsensitivität von input4: 0.015158
# Gesamtsensitivität von input5: 0.000000
# Gesamtsensitivität von input6: 0.016778
# Gesamtsensitivität von input7: 0.003507
# Gesamtsensitivität von input8: 0.000000
# Gesamtsensitivität von input9: 0.225867
# Gesamtsensitivität von input10: 0.000000
# Gesamtsensitivität von input11: 0.008145
# Gesamtsensitivität von input12: 0.003294
# Gesamtsensitivität von input13: 0.000000
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 5
#
#
# Gesamtsensitivität von input0: 0.202506
# Gesamtsensitivität von input1: 0.140579
# Gesamtsensitivität von input2: 0.417469
# Gesamtsensitivität von input3: 0.044501
# Gesamtsensitivität von input4: 0.094189
# Gesamtsensitivität von input5: 0.000000
# Gesamtsensitivität von input6: 0.106934
# Gesamtsensitivität von input7: 0.022014
# Gesamtsensitivität von input8: 0.000000
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.000001
# Gesamtsensitivität von input11: 0.005259
# Gesamtsensitivität von input12: 0.005879
# Gesamtsensitivität von input13: 0.000000
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 6
#
#
# Gesamtsensitivität von input0: 0.010627
# Gesamtsensitivität von input1: 0.049488
# Gesamtsensitivität von input2: 0.063739
# Gesamtsensitivität von input3: 0.152816
# Gesamtsensitivität von input4: 0.329128
# Gesamtsensitivität von input5: 0.000000
# Gesamtsensitivität von input6: 0.375612
# Gesamtsensitivität von input7: 0.075199
# Gesamtsensitivität von input8: 0.000000
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.000000
# Gesamtsensitivität von input11: 0.005664
# Gesamtsensitivität von input12: 0.003662
# Gesamtsensitivität von input13: 0.000000
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 7
#
#
# Gesamtsensitivität von input0: 0.000000
# Gesamtsensitivität von input1: 0.000000
# Gesamtsensitivität von input2: 0.000000
# Gesamtsensitivität von input3: 0.000000
# Gesamtsensitivität von input4: 0.000000
# Gesamtsensitivität von input5: 0.000000
# Gesamtsensitivität von input6: 0.000000
# Gesamtsensitivität von input7: 0.000000
# Gesamtsensitivität von input8: 0.000000
# Gesamtsensitivität von input9: 1.000568
# Gesamtsensitivität von input10: 0.000000
# Gesamtsensitivität von input11: 0.000000
# Gesamtsensitivität von input12: 0.000000
# Gesamtsensitivität von input13: 0.000000
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 8
#
#
# Gesamtsensitivität von input0: 0.003907
# Gesamtsensitivität von input1: 0.360770
# Gesamtsensitivität von input2: 0.119780
# Gesamtsensitivität von input3: 0.018888
# Gesamtsensitivität von input4: 0.040284
# Gesamtsensitivität von input5: 0.408688
# Gesamtsensitivität von input6: 0.046721
# Gesamtsensitivität von input7: 0.010016
# Gesamtsensitivität von input8: 0.000000
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.009942
# Gesamtsensitivität von input11: 0.010963
# Gesamtsensitivität von input12: 0.009587
# Gesamtsensitivität von input13: 0.000000
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
#
#
# Ergebnisse der Sensitivitätsanalyse von output: 9
#
#
# Gesamtsensitivität von input0: 0.043109
# Gesamtsensitivität von input1: 0.206096
# Gesamtsensitivität von input2: 0.330405
# Gesamtsensitivität von input3: 0.064715
# Gesamtsensitivität von input4: 0.138922
# Gesamtsensitivität von input5: 0.000000
# Gesamtsensitivität von input6: 0.155341
# Gesamtsensitivität von input7: 0.029875
# Gesamtsensitivität von input8: 0.000000
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.001440
# Gesamtsensitivität von input11: 0.014578
# Gesamtsensitivität von input12: 0.033579
# Gesamtsensitivität von input13: 0.000000
# Gesamtsensitivität von input14: 0.000000
# Gesamtsensitivität von input15: 0.004715
# Gesamtsensitivität von input16: 0.000000
# Gesamtsensitivität von input17: 0.018055
# --------------------------------------------------------------
# Ergebnisse der Sensitivitätsanalyse von output: 10
#
#
# Gesamtsensitivität von input0: 0.011761
# Gesamtsensitivität von input1: 0.073233
# Gesamtsensitivität von input2: 0.051610
# Gesamtsensitivität von input3: 0.017636
# Gesamtsensitivität von input4: 0.037835
# Gesamtsensitivität von input5: 0.000000
# Gesamtsensitivität von input6: 0.043383
# Gesamtsensitivität von input7: 0.009018
# Gesamtsensitivität von input8: 0.748488
# Gesamtsensitivität von input9: 0.000000
# Gesamtsensitivität von input10: 0.011825
# Gesamtsensitivität von input11: 0.008898
# Gesamtsensitivität von input12: 0.009214
# Gesamtsensitivität von input13: 0.000000
# Gesamtsensitivität von input14: 0.079767
# Gesamtsensitivität von input15: 0.000000
# Gesamtsensitivität von input16: 0.003076
# Gesamtsensitivität von input17: 0.000000
# --------------------------------------------------------------
